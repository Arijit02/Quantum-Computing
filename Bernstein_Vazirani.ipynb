# %% [markdown]
# <a href="https://colab.research.google.com/github/Arijit02/Quantum-Computing/blob/master/Bernstein_Vazirani.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit
from qiskit import *
# %matplotlib inline
from qiskit.tools.visualization import plot_histogram
# Out:
# ...
#      |████████████████████████████████| 6.7MB 3.1MB/s
# ...
#      |████████████████████████████████| 23.3MB 1.6MB/s
# ...
#      |████████████████████████████████| 163kB 42.5MB/s
# ...
#      |████████████████████████████████| 174kB 46.1MB/s
# ...
#      |████████████████████████████████| 1.9MB 44.8MB/s
# ...
#      |████████████████████████████████| 5.8MB 41.6MB/s
# ...
#      |████████████████████████████████| 51kB 6.3MB/s
# ...
#      |████████████████████████████████| 768kB 42.8MB/s
# ...
#      |████████████████████████████████| 51kB 6.4MB/s
# ...
#      |████████████████████████████████| 296kB 45.6MB/s
# ...
#      |████████████████████████████████| 71kB 8.6MB/s
# ...
#      |████████████████████████████████| 573kB 39.2MB/s
# ...
#      |████████████████████████████████| 26.0MB 1.3MB/s
# ...
#      |████████████████████████████████| 2.7MB 45.7MB/s
# ...
#   Created wheel for qiskit: filename=qiskit-0.19.4-cp36-none-any.whl size=2897 sha256=1e6c24d71e54ce456ccde3e58f7035fc2849af46749345276b7940883e9f3a28
# ...

# %%
secret_number = '101001'

# %%
length = len(secret_number)
circuit = QuantumCircuit(length+1, length)
# circuit.h([0, 1, 2, 3, 4, 5])
circuit.h(range(length))
circuit.x(length)
circuit.h(length)
circuit.barrier()
circuit.draw(output='mpl')

# %%
for i, yesno in enumerate(reversed(secret_number)):
  if yesno == '1':
    circuit.cx(i, length)

# circuit.cx(5, 6)
# circuit.cx(3, 6)
# circuit.cx(0, 6)
circuit.barrier()
circuit.draw(output='mpl')

# %%
circuit.h(range(length))
circuit.barrier()
circuit.draw(output='mpl')

# %%
circuit.measure(range(length), range(length))
circuit.draw(output='mpl')

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(circuit, backend=simulator, shots=1).result()
count = result.get_counts(circuit)
print(count)
# Out:
# {'101001': 1}
